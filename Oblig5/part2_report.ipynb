# %% [markdown]
# # Problem set 5 - Part II: Report
# ## Exercise 5 Function Approximation And Policy Gradient

# %% [markdown]
# ### 1. Episodic vs continuing
# There is no end terminal state as the cookies keep falling from the conveyor belt immediately after the previous one has either been collected or has dissapeared. Therefore it would most naturally be described as a continuing task.
#
# It should be noted that when we define the number of steps in an episode, the task is treated as episodic.

# %% [markdown]
# ### 2. Linear approximation to approximate qπ(a, s)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Neural network to approximate qπ(a, s)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.(*) Explain the two solutions and comment on the results
#
# The linear approximation in this case is actually quicker at getting to a stable positive reward. After around 75 episodes it does not return a negative reward. But in turn performance is limited, with the linear approximator struggling to get a return above 10.
#
# The Neural Network approximator is slightly slower at getting above the positive return threshold, but with a more clear improvement with increasing episodes. It avoids alot of the crashes the linear approximation struggles with and averages returns above 10, almost reaching 20 between episode 350 to 400.
#
# The returns for both models have noticeable drops in regular intervals, more so for the linear approximation model. This is expected, but could be mitigated using a higher epsilon.

# %% [markdown]
# ### 5. Implement actor-critic model
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. (*) Explain the actor-critic solution and compare results
#
# ##### Solution
#
# ##### Results
# ![image.png](attachment:image.png)
#
# With the improvements the speed of improvement vastly outperformes the two previous models. After less than 100 episodes the Actor-critic model returns rewards above 20, before plateauing with an average between 20 and 25.
#
# The model with replay buffer and target network is also in this plot. It shows a speed of learning slightly better than the neural network model, and it takes 250 episodes for it to catch up to the actor-critic model. It makes up for this by surpassing the actor-critic models average rewards and reaching returns above 30 points.

# %% [markdown]
# #### 7. Improve solution by adding a replay buffer and target network
# ![image.png](attachment:image.png)
